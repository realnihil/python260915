# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np  

plt.plot(np.arange(10))

# %%
#아래와 같이 선언할 수 있다
from pandas import Series, DataFrame
#또는 아래와 같이 선언하기도 한다. 
import pandas as pd

# %%
myCampus = Series([31500, 31300, 31000, 31200, 31300, 31400])
myCampus
# Out:
# 0    31500
# 1    31300
# 2    31000
# 3    31200
# 4    31300
# 5    31400
# dtype: int64

# %%
myCampus = Series([31500, 31300, 31000, 31200, 31300, 31400],
    index=["2023-01-10","2023-01-11","2023-01-12","2023-01-13","2023-01-14",
    "2023-01-15"])
myCampus
# Out:
# 2023-01-10    31500
# 2023-01-11    31300
# 2023-01-12    31000
# 2023-01-13    31200
# 2023-01-14    31300
# 2023-01-15    31400
# dtype: int64

# %%
myCampus["2023-01-10"]
# Out:
# np.int64(31500)

# %%
data = { "foreigner":[1, 2, 3, 4, 5, 6], 
         "sratio":[10, 20, 30, 40, 50, 60], 
         "org":[100, 200, 300, 400, 500, 600], 
         "sprice":[1, 2, 3, 4, 5, 6], 
         "private":[10, 20, 30, 40, 50, 60] }

data
# Out:
# {'foreigner': [1, 2, 3, 4, 5, 6],
#  'sratio': [10, 20, 30, 40, 50, 60],
#  'org': [100, 200, 300, 400, 500, 600],
#  'sprice': [1, 2, 3, 4, 5, 6],
#  'private': [10, 20, 30, 40, 50, 60]}

# %%
frame = DataFrame(data)
print(type(frame))
# Out:
# <class 'pandas.DataFrame'>

# %%
frame
# Out:
#    foreigner  sratio  org  sprice  private
# 0          1      10  100       1       10
# 1          2      20  200       2       20
# 2          3      30  300       3       30
# 3          4      40  400       4       40
# 4          5      50  500       5       50
# 5          6      60  600       6       60

# %%
frame2 = DataFrame(data, 
    columns=["foreigner", "private", "sratio", "org", "sprice"])
frame2
# Out:
#    foreigner  private  sratio  org  sprice
# 0          1       10      10  100       1
# 1          2       20      20  200       2
# 2          3       30      30  300       3
# 3          4       40      40  400       4
# 4          5       50      50  500       5
# 5          6       60      60  600       6

# %%
frame2["private"]
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: private, dtype: int64

# %%
#색인을 날짜시간기반으로 변경한 경우 
frame2 = DataFrame(data, 
    columns=["foreigner", "private", "sratio", "org", "sprice"],
    index=["2026-01-03","2026-01-04","2026-01-05","2026-01-06",
        "2026-01-07","2026-01-08"])
frame2
# Out:
#             foreigner  private  sratio  org  sprice
# 2026-01-03          1       10      10  100       1
# 2026-01-04          2       20      20  200       2
# 2026-01-05          3       30      30  300       3
# 2026-01-06          4       40      40  400       4
# 2026-01-07          5       50      50  500       5
# 2026-01-08          6       60      60  600       6

# %%
frame2["private"]
# Out:
# 2026-01-03    10
# 2026-01-04    20
# 2026-01-05    30
# 2026-01-06    40
# 2026-01-07    50
# 2026-01-08    60
# Name: private, dtype: int64

# %%
frame2.loc["2026-01-03"]
# Out:
# foreigner      1
# private       10
# sratio        10
# org          100
# sprice         1
# Name: 2026-01-03, dtype: int64

# %%
frame2.T
# Out:
#            2026-01-03  2026-01-04  2026-01-05  2026-01-06  2026-01-07  \
# foreigner           1           2           3           4           5
# private            10          20          30          40          50
# sratio             10          20          30          40          50
# org               100         200         300         400         500
# sprice              1           2           3           4           5
#
#            2026-01-08
# foreigner           6
# private            60
# sratio             60
# org               600
# sprice              6

# %%
# !type c:\work\ex1.csv
# Out:
# id, name, price, description
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
import pandas as pd 

frame = pd.read_csv("c:\\work\\ex1.csv")
frame
# Out:
#    id       name    price           description
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
# !type c:\work\ex2.csv
# Out:
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
frame2 = pd.read_csv("c:\\work\\ex2.csv", 
    names=["id","name","price","desc"])
frame2
# Out:
#    id       name    price                  desc
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
result = pd.read_table('c:\work\ex3.txt', sep='\s+')
result
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\student\AppData\Local\Temp\ipykernel_17468\3012293989.py:1: SyntaxWarning: invalid escape sequence '\w'
#   result = pd.read_table('c:\work\ex3.txt', sep='\s+')
# C:\Users\student\AppData\Local\Temp\ipykernel_17468\3012293989.py:1: SyntaxWarning: invalid escape sequence '\s'
#   result = pd.read_table('c:\work\ex3.txt', sep='\s+')
#    data1  data2  data3
# 0    1.2    2.3    1.3
# 1    0.1    1.5    2.5
# 2    3.1    3.2    3.3

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('c:\\work\\demo.xlsx', 'Sheet1')
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(df['나이'], bins = 7)
# Out:
# (array([1., 1., 2., 3., 1., 1., 1.]),
#  array([26.        , 28.57142857, 31.14285714, 33.71428571, 36.28571429,
#         38.85714286, 41.42857143, 44.        ]),
#  <BarContainer object of 7 artists>)
