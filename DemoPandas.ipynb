# %%
# DemoPandas.ipynb 저장
# %matplotlib inline
from pandas import Series, DataFrame
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 시리즈 객체 생성
myCampus = Series(data = [100,200,300,400,500],
index = ['2026-09-15','2026-09-16','2026-09-17',
         '2026-09-18','2026-09-19'])
# 슬라이싱
myCampus['2026-09-15']
# Out:
# np.int64(100)

# %%
# 딕셔너리를 데이터프레임으로 변환
data = {'foreigner':[1,2,3,4,5,6],
        'sratio':[10,20,30,40,50,60],
        'org':[100,200,300,400,500,600],
        'sprice':[1,2,3,4,5,6],
        'private':[10,20,30,40,50,60]}

df = DataFrame(data)
df

# %%
df2 = DataFrame(data=data, 
                columns=['private', 'org', 'foreigner', 'sratio', 'sprice'],)
                # index = ['2026년9월15일', '2026년9월16일', '2026년9월17일', '2026년9월18일', '2026년9월19일','2026년9월20일'])
df2
# Out:
#    private  org  foreigner  sratio  sprice
# 0       10  100          1      10       1
# 1       20  200          2      20       2
# 2       30  300          3      30       3
# 3       40  400          4      40       4
# 4       50  500          5      50       5
# 5       60  600          6      60       6

# %%
# df2.loc["2026년9월15일"]
df2.loc[0]
# Out:
# private       10
# org          100
# foreigner      1
# sratio        10
# sprice         1
# Name: 0, dtype: int64

# %%
df2['private']
# Out:
# 2026년9월15일    10
# 2026년9월16일    20
# 2026년9월17일    30
# 2026년9월18일    40
# 2026년9월19일    50
# 2026년9월20일    60
# Name: private, dtype: int64

# %%
df3 = df2.columns[0:1]
idx = df2['foreigner'] == 1
idx
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: foreigner, dtype: bool

# %%
df2.loc[idx]
# Out:
#    private  org  foreigner  sratio  sprice
# 0       10  100          1      10       1

# %%
df2['date'] = pd.date_range('2026-09-15', periods=len(df2), freq='D')
df2
# Out:
#    private  org  foreigner  sratio  sprice       date
# 0       10  100          1      10       1 2026-09-15
# 1       20  200          2      20       2 2026-09-16
# 2       30  300          3      30       3 2026-09-17
# 3       40  400          4      40       4 2026-09-18
# 4       50  500          5      50       5 2026-09-19
# 5       60  600          6      60       6 2026-09-20

# %%
idx = df2['date'] == '2026-09-15'
df2.loc[idx]
# Out:
#    private  org  foreigner  sratio  sprice       date
# 0       10  100          1      10       1 2026-09-15

# %%
# !type c:\work\sample.tle
# tle1 = pd.read_fwf(r'C:\work\sample.tle',
#                    names=[])
# tle1
# tle2 = pd.read_table(r'C:\work\sample.tle',sep=r'\s+',
#                      header=None,
#                      index_col=False)
tle2 = pd.read_table(r'C:\work\sample.tle',sep=r'\s+',
                     names=['1','2','3','4','5','6','7','8'])
tle2
# a = tle2.loc[1]
# a.loc['44058U']
# print(type(a))
# b = tle2.loc[2]
# b
# Out:
#         1        2             3             4        5         6          7  \
# 1  44057U   19010A  26260.589482  2.000000e-08  00000+0  -27756-4   0.000000
# 2   44057  87.9141    210.435100  2.455000e+03  85.0003  275.1408  13.165939
# 1  44058U   19010B  26260.310826  9.800000e-07  00000+0   22165-3   0.000000
# 2   44058  87.9158    210.490900  1.876000e+03  69.0616  291.0715  13.165932
# 1  44059U   19010C  26260.336162  3.800000e-07  00000+0   65657-4   0.000000
# 2   44059  87.9150    210.479900  1.895000e+03  90.1580  269.9768  13.165939
#
#         8
# 1  9997.0
# 2     NaN
# 1  9999.0
# 2     NaN
# 1  9998.0
# 2     NaN

# %%
# tle2[:].loc[1]
a = tle2.loc[1]
c = a.iloc[0]
c
# Out:
# 1          44057U
# 2          19010A
# 3    26260.589482
# 4             0.0
# 5         00000+0
# 6        -27756-4
# 7             0.0
# 8          9997.0
# Name: 1, dtype: object

# %%
b = tle2.loc[2]
b
# Out:
#        1        2         3       4        5         6          7   8
# 2  44057  87.9141  210.4351  2455.0  85.0003  275.1408  13.165939 NaN
# 2  44058  87.9158  210.4909  1876.0  69.0616  291.0715  13.165932 NaN
# 2  44059  87.9150  210.4799  1895.0  90.1580  269.9768  13.165939 NaN

# %%
# 파일에서 Dataframe으로 로딩
# !type c:\work\ex1.csv
# Out:
# id, name, price, description
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
data1 = pd.read_csv('c:\\work\\ex1.csv')
data1
# Out:
#    id       name    price           description
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
data2 = pd.read_csv('c:\\work\\ex2.csv',
                    names=['id', 'name', 'price', 'description'])
data2
# Out:
#    1     iphone   1990000            iphone 17
# 0  2    android   1590000         samsung phone
# 1  3   winphone    850000   microsoft winphone

# %%
# !type c:\work\ex3.txt
# Out:
# data1 data2 data3
# 1.2     2.3     1.3
# 0.1     1.5     2.5
# 3.1     3.2     3.3

# %%
#특수문자 r : raw string notation
data3 = pd.read_table(r'c:\work\ex3.txt', sep=r'\s+')
data3
# Out:
#    data1  data2  data3
# 0    1.2    2.3    1.3
# 1    0.1    1.5    2.5
# 2    3.1    3.2    3.3

# %%
dfExcel = pd.read_excel(r'c:\work\demo.xlsx', 'Sheet1')
# dfExcel
# 그림판 생성
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(dfExcel["나이"],  bins=7)
# Out:
# (array([1., 1., 2., 3., 1., 1., 1.]),
#  array([26.        , 28.57142857, 31.14285714, 33.71428571, 36.28571429,
#         38.85714286, 41.42857143, 44.        ]),
#  <BarContainer object of 7 artists>)
